# %%
# auto reload when source code changes
# %load_ext autoreload
# %autoreload 2

# include parent folder in path
import os, sys
sys.path.append("..") # Adds higher directory to python modules path.

import aicsPlot
# Out:
# /home/cudmore/anaconda3/envs/sanode-env/lib/python3.6/site-packages/skan/csr.py:21: NumbaDeprecationWarning:
#
# The 'numba.jitclass' decorator has moved to 'numba.experimental.jitclass' to better reflect the experimental nature of the functionality. Please update your imports to accommodate this change and see https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#change-of-jitclass-location for the time frame.

# %%
channel = 1
csvFile = f'../../Density-Result-ch{channel}.csv'
supList, infList, axs = aicsPlot.plotMaskDensity(channel=channel, csvFile=csvFile)

channel = 2
csvFile = f'../../Density-Result-ch{channel}.csv'
supList, infList, axs = aicsPlot.plotMaskDensity(channel=channel, csvFile=csvFile)
# Out:
#    SAN1 [41.28484419616179, 19.0087801314828]
#    SAN2 [73.05932210118459, 18.4106051285994]
#    SAN3 [23.147127184783503, 45.9080166348633]
#    SAN4 [29.327681984827105, 11.6720388164397]
#    SAN7 [46.570582386363604, 25.1020265151515]
#    SAN8 [64.6797388604821, 52.94111079752971]
#   plotMaskDensity superiorList: [41.28484419616179, 73.05932210118459, 23.147127184783503, 29.327681984827105, 46.570582386363604, 64.6797388604821]
#   plotMaskDensity inferiorList: [19.0087801314828, 18.4106051285994, 45.9080166348633, 11.6720388164397, 25.1020265151515, 52.94111079752971]
# mean:46.34 sd:17.81 sem:7.27 n:6 min:23.15 max:73.06 median:43.93
# mean:28.84 sd:15.20 sem:6.21 n:6 min:11.67 max:52.94 median:22.06
# wilcoxon stat: 16.0 p: 0.15625
#    SAN1 [21.256964273856198, 19.0087801314828]
#    SAN2 [28.1569735128783, 20.692985659913102]
#    SAN3 [15.486733644986801, 12.685823140878401]
#    SAN4 [23.742719589632202, 14.5016489064581]
#    SAN7 [20.6944223484848, 13.4186079545455]
#    SAN8 [37.550607195032896, 27.6038540075702]
#   plotMaskDensity superiorList: [21.256964273856198, 28.1569735128783, 15.486733644986801, 23.742719589632202, 20.6944223484848, 37.550607195032896]
#   plotMaskDensity inferiorList: [19.0087801314828, 20.692985659913102, 12.685823140878401, 14.5016489064581, 13.4186079545455, 27.6038540075702]
# mean:24.48 sd:6.96 sem:2.84 n:6 min:15.49 max:37.55 median:22.50
# mean:17.99 sd:5.20 sem:2.12 n:6 min:12.69 max:27.60 median:16.76
# wilcoxon stat: 21.0 p: 0.015625

# %%
# this requires a file
#os.path.isfile('../../hcn4-Distance-Result.csv')

# this file is created in aicsMyocyteDistanceToVasc.py

#aicsPlot.plotMeanDist(csvFile='../../hcn4-Distance-Result.csv')
aicsPlot.plotMeanDist(csvFile='../../hcn4-Distance-Result-20210324.csv')
# Out:
# SAN1 [2.61792230606079, 3.93526744842529]
# SAN2 [2.7070512771606405, 4.31861019134522]
# SAN3 [3.00351452827454, 8.01746940612793]
# SAN4 [2.67742156982422, 4.97184705734253]
# SAN7 [2.0774462223053, 3.89873814582825]
# SAN8 [2.15239691734314, 2.98498892784119]
# mean:2.54 sd:0.32 sem:0.13 n:6 min:2.08 max:3.00 median:2.65
# mean:4.69 sd:1.60 sem:0.65 n:6 min:2.98 max:8.02 median:4.13
# wilcoxon stat: 0.0 p: 0.03125
# paired ttest stat: -3.540152035548309 pValue: 0.016559895851381276
# SAN1 [2.61792230606079, 3.93526744842529]
# SAN2 [2.7070512771606405, 4.31861019134522]
# SAN3 [3.00351452827454, 8.01746940612793]
# SAN4 [2.67742156982422, 4.97184705734253]
# SAN7 [2.0774462223053, 3.89873814582825]
# SAN8 [2.15239691734314, 2.98498892784119]
# mean:2.54 sd:0.32 sem:0.13 n:6 min:2.08 max:3.00 median:2.65
# mean:4.69 sd:1.60 sem:0.65 n:6 min:2.98 max:8.02 median:4.13
# wilcoxon stat: 0.0 p: 0.03125
# paired ttest stat: -3.540152035548309 pValue: 0.016559895851381276
# ([2.61792230606079,
#   2.7070512771606405,
#   3.00351452827454,
#   2.67742156982422,
#   2.0774462223053,
#   2.15239691734314],
#  [3.93526744842529,
#   4.31861019134522,
#   8.01746940612793,
#   4.97184705734253,
#   3.89873814582825,
#   2.98498892784119],
#  <AxesSubplot:ylabel='Median HCN4 Distance\nto Vasculature ($\\mu$m)'>)

# %%
# SAN2
'''
pathList = [
    '/media/cudmore/data/san-density/SAN2/SAN2_head/aicsAnalysis/SAN2_head_ch2.tif',
    '/media/cudmore/data/san-density/SAN2/SAN2_mid/aicsAnalysis/SAN2_mid_ch2.tif',
    '/media/cudmore/data/san-density/SAN2/SAN2_tail/aicsAnalysis/SAN2_tail_ch2.tif',
    ]
'''
# SAN3
'''
pathList = [
    '/media/cudmore/data/san-density/SAN3/SAN3_head/aicsAnalysis/SAN3_head_ch2.tif',
    '/media/cudmore/data/san-density/SAN3/SAN3_mid/aicsAnalysis/SAN3_mid_ch2.tif',
    '/media/cudmore/data/san-density/SAN3/SAN3_tail/aicsAnalysis/SAN3_tail_ch2.tif',
    ]
'''
# SAN4
pathList = [
    '/media/cudmore/data/san-density/SAN4/SAN4_head/aicsAnalysis/SAN4_head_ch2.tif',
    '/media/cudmore/data/san-density/SAN4/SAN4_mid/aicsAnalysis/SAN4_mid_ch2.tif',
    '/media/cudmore/data/san-density/SAN4/SAN4_tail/aicsAnalysis/SAN4_tail_ch2.tif',
    ]

# %%
# Out:
# UsageError: %%capture is a cell magic, but the cell body is empty.

# %%
aicsPlot.plotSlabDiamHist(pathList)
# Out:
# todo: bAnnotationList needs to save/load into main h5f file !!!!!!!
#
# bVascularTracing.__init__() loadTracing: True path: /media/cudmore/data/san-density/SAN4/SAN4_head/aicsAnalysis/SAN4_head_ch2.tif
# === bVascularTracing.load() /media/cudmore/data/san-density/SAN4/SAN4_head/aicsAnalysis/SAN4_head_ch2.h5f
#     loaded nodes: 1887 edges: 2402 slabs: 47241 in 0.31 seconds
#   xVoxel: 0.49718469168334306
#   yVoxel: 0.49718469168334306
#
# todo: bAnnotationList needs to save/load into main h5f file !!!!!!!
#
# bVascularTracing.__init__() loadTracing: True path: /media/cudmore/data/san-density/SAN4/SAN4_mid/aicsAnalysis/SAN4_mid_ch2.tif
# === bVascularTracing.load() /media/cudmore/data/san-density/SAN4/SAN4_mid/aicsAnalysis/SAN4_mid_ch2.h5f
#     loaded nodes: 1608 edges: 2092 slabs: 51837 in 0.27 seconds
#   xVoxel: 0.49718469168334306
#   yVoxel: 0.49718469168334306
#
# todo: bAnnotationList needs to save/load into main h5f file !!!!!!!
#
# bVascularTracing.__init__() loadTracing: True path: /media/cudmore/data/san-density/SAN4/SAN4_tail/aicsAnalysis/SAN4_tail_ch2.tif
# === bVascularTracing.load() /media/cudmore/data/san-density/SAN4/SAN4_tail/aicsAnalysis/SAN4_tail_ch2.h5f
#     loaded nodes: 688 edges: 816 slabs: 30343 in 0.11 seconds
#   xVoxel: 0.49718469168334306
#   yVoxel: 0.49718469168334306
#   mean:6.186511195616941 sd:1.8151444038922953 n:27945 min:2.4859234584167154 max:12.92680198376692 path:/media/cudmore/data/san-density/SAN4/SAN4_head/aicsAnalysis/SAN4_head_ch2.tif
#   mean:6.204703755138957 sd:1.666703071063847 n:33064 min:2.4859234584167154 max:12.92680198376692 path:/media/cudmore/data/san-density/SAN4/SAN4_mid/aicsAnalysis/SAN4_mid_ch2.tif
#   mean:5.625699454375658 sd:1.8508743134559575 n:21145 min:2.4859234584167154 max:12.92680198376692 path:/media/cudmore/data/san-density/SAN4/SAN4_tail/aicsAnalysis/SAN4_tail_ch2.tif

# %%
aicsPlot.plotEdgeDiamHist(pathList)
# Out:
# plotEdgeDiamHist():
#
# todo: bAnnotationList needs to save/load into main h5f file !!!!!!!
#
# bVascularTracing.__init__() loadTracing: True path: /media/cudmore/data/san-density/SAN4/SAN4_head/aicsAnalysis/SAN4_head_ch2.tif
# === bVascularTracing.load() /media/cudmore/data/san-density/SAN4/SAN4_head/aicsAnalysis/SAN4_head_ch2.h5f
#     loaded nodes: 1887 edges: 2402 slabs: 47241 in 0.33 seconds
#   xVoxel: 0.49718469168334306
#   yVoxel: 0.49718469168334306
#
# todo: bAnnotationList needs to save/load into main h5f file !!!!!!!
#
# bVascularTracing.__init__() loadTracing: True path: /media/cudmore/data/san-density/SAN4/SAN4_mid/aicsAnalysis/SAN4_mid_ch2.tif
# === bVascularTracing.load() /media/cudmore/data/san-density/SAN4/SAN4_mid/aicsAnalysis/SAN4_mid_ch2.h5f
#     loaded nodes: 1608 edges: 2092 slabs: 51837 in 0.28 seconds
#   xVoxel: 0.49718469168334306
#   yVoxel: 0.49718469168334306
#
# todo: bAnnotationList needs to save/load into main h5f file !!!!!!!
#
# bVascularTracing.__init__() loadTracing: True path: /media/cudmore/data/san-density/SAN4/SAN4_tail/aicsAnalysis/SAN4_tail_ch2.tif
# === bVascularTracing.load() /media/cudmore/data/san-density/SAN4/SAN4_tail/aicsAnalysis/SAN4_tail_ch2.h5f
#     loaded nodes: 688 edges: 816 slabs: 30343 in 0.11 seconds
#   xVoxel: 0.49718469168334306
#   yVoxel: 0.49718469168334306
#   minNumberOfSlabs: 5
#   mean:6.644246468706816 sd:1.5623265359348535 n:1709 min:2.9831081501000583 max:11.932432600400233 path:/media/cudmore/data/san-density/SAN4/SAN4_head/aicsAnalysis/SAN4_head_ch2.tif
#   minNumberOfSlabs: 5
#   mean:6.7819960240310735 sd:1.6092908846836635 n:1516 min:3.4802928417834016 max:12.429617292083577 path:/media/cudmore/data/san-density/SAN4/SAN4_mid/aicsAnalysis/SAN4_mid_ch2.tif
#   minNumberOfSlabs: 5
#   mean:6.154942911355003 sd:1.7333225497714613 n:635 min:2.4859234584167154 max:11.932432600400233 path:/media/cudmore/data/san-density/SAN4/SAN4_tail/aicsAnalysis/SAN4_tail_ch2.tif
